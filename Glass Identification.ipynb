# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt            # Importing necessary libraries
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Glass_identification.csv',header=None)
df.columns = ['Id number','refractive index','Sodium','Magnesium','Aluminum','Silicon','Potassium','Calcium','Barium','Iron','Type of glass'] 
df
# Out:
#      Id number  refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 0            1           1.52101   13.64       4.49      1.10    71.78
# 1            2           1.51761   13.89       3.60      1.36    72.73
# 2            3           1.51618   13.53       3.55      1.54    72.99
# 3            4           1.51766   13.21       3.69      1.29    72.61
# 4            5           1.51742   13.27       3.62      1.24    73.08
# ..         ...               ...     ...        ...       ...      ...
# 209        210           1.51623   14.14       0.00      2.88    72.61
# 210        211           1.51685   14.92       0.00      1.99    73.06
# 211        212           1.52065   14.36       0.00      2.02    73.42
# 212        213           1.51651   14.38       0.00      1.94    73.61
# 213        214           1.51711   14.23       0.00      2.08    73.36
#
#      Potassium  Calcium  Barium  Iron  Type of glass
# 0         0.06     8.75    0.00   0.0              1
# ...

# %%
df.head()
# Out:
#    Id number  refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 0          1           1.52101   13.64       4.49      1.10    71.78
# 1          2           1.51761   13.89       3.60      1.36    72.73
# 2          3           1.51618   13.53       3.55      1.54    72.99
# 3          4           1.51766   13.21       3.69      1.29    72.61
# 4          5           1.51742   13.27       3.62      1.24    73.08
#
#    Potassium  Calcium  Barium  Iron  Type of glass
# 0       0.06     8.75     0.0   0.0              1
# 1       0.48     7.83     0.0   0.0              1
# 2       0.39     7.78     0.0   0.0              1
# 3       0.57     8.22     0.0   0.0              1
# 4       0.55     8.07     0.0   0.0              1

# %%
df.tail()
# Out:
#      Id number  refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 209        210           1.51623   14.14        0.0      2.88    72.61
# 210        211           1.51685   14.92        0.0      1.99    73.06
# 211        212           1.52065   14.36        0.0      2.02    73.42
# 212        213           1.51651   14.38        0.0      1.94    73.61
# 213        214           1.51711   14.23        0.0      2.08    73.36
#
#      Potassium  Calcium  Barium  Iron  Type of glass
# 209       0.08     9.18    1.06   0.0              7
# 210       0.00     8.40    1.59   0.0              7
# 211       0.00     8.44    1.64   0.0              7
# 212       0.00     8.48    1.57   0.0              7
# 213       0.00     8.62    1.67   0.0              7

# %%
df.sample()
# Out:
#     Id number  refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 72         73           1.51593   13.09       3.59      1.52     73.1
#
#     Potassium  Calcium  Barium  Iron  Type of glass
# 72       0.67     7.83     0.0   0.0              2

# %%
df.shape          # This dataset has 214 rows and 11 columns
# Out:
# (214, 11)

# %%
df.columns.tolist()       # These are the column names present in the dataset.
# Out:
# ['Id number',
#  'refractive index',
#  'Sodium',
#  'Magnesium',
#  'Aluminum',
#  'Silicon',
#  'Potassium',
#  'Calcium',
#  'Barium',
#  'Iron',
#  'Type of glass']

# %%
df.dtypes           # This shows two types of data is present in the dataset, int64,float64
# Out:
# Id number             int64
# refractive index    float64
# Sodium              float64
# Magnesium           float64
# Aluminum            float64
# Silicon             float64
# Potassium           float64
# Calcium             float64
# Barium              float64
# Iron                float64
# Type of glass         int64
# dtype: object

# %%
df.info()          # This shows no null value present in the dataset & memory usage is 18.5KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id number         214 non-null    int64
#  1   refractive index  214 non-null    float64
#  2   Sodium            214 non-null    float64
#  3   Magnesium         214 non-null    float64
#  4   Aluminum          214 non-null    float64
#  5   Silicon           214 non-null    float64
#  6   Potassium         214 non-null    float64
#  7   Calcium           214 non-null    float64
#  8   Barium            214 non-null    float64
#  9   Iron              214 non-null    float64
#  10  Type of glass     214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
df.isnull().sum()        # No null values
# Out:
# Id number           0
# refractive index    0
# Sodium              0
# Magnesium           0
# Aluminum            0
# Silicon             0
# Potassium           0
# Calcium             0
# Barium              0
# Iron                0
# Type of glass       0
# dtype: int64

# %%
sns.heatmap(df.isnull())            # Visualizing with heatmap no null values are present in the dataset.
# Out:
# <AxesSubplot:>

# %%
for i in df.columns:                # There is no wide values are present in the dataset & Our target variable is Type of glass
    print(df[i].value_counts())     # Its a classification problem.
    print("\n")
# Out:
# 1      1
# 135    1
# 137    1
# 138    1
# 139    1
#       ..
# 75     1
# 76     1
# 77     1
# 78     1
# 214    1
# Name: Id number, Length: 214, dtype: int64
#
#
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: refractive index, Length: 178, dtype: int64
#
#
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Sodium, Length: 142, dtype: int64
#
#
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Magnesium, Length: 94, dtype: int64
#
#
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: Aluminum, Length: 118, dtype: int64
#
#
# 72.86    4
# 72.99    4
# 73.10    4
# ...

# %%
df['Type of glass'].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type of glass, dtype: int64

# %%
df['Potassium'].value_counts()
# Out:
# 0.00    30
# 0.57    12
# 0.56    11
# 0.60    11
# 0.58    10
#         ..
# 0.44     1
# 0.07     1
# 0.73     1
# 0.70     1
# 1.41     1
# Name: Potassium, Length: 65, dtype: int64

# %%
df['Calcium'].value_counts()
# Out:
# 8.03    5
# 8.43    5
# 9.57    4
# 8.79    4
# 8.44    4
#        ..
# 9.23    1
# 8.90    1
# 9.13    1
# 8.09    1
# 8.62    1
# Name: Calcium, Length: 143, dtype: int64

# %%
df.duplicated().sum()        # No duplicate values are present in the dataset
# Out:
# 0

# %%
df.describe()
# Out:
#         Id number  refractive index      Sodium   Magnesium    Aluminum  \
# count  214.000000        214.000000  214.000000  214.000000  214.000000
# mean   107.500000          1.518365   13.407850    2.684533    1.444907
# std     61.920648          0.003037    0.816604    1.442408    0.499270
# min      1.000000          1.511150   10.730000    0.000000    0.290000
# 25%     54.250000          1.516522   12.907500    2.115000    1.190000
# 50%    107.500000          1.517680   13.300000    3.480000    1.360000
# 75%    160.750000          1.519157   13.825000    3.600000    1.630000
# max    214.000000          1.533930   17.380000    4.490000    3.500000
#
#           Silicon   Potassium     Calcium      Barium        Iron  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean    72.650935    0.497056    8.956963    0.175047    0.057009
# std      0.774546    0.652192    1.423153    0.497219    0.097439
# ...

# %% [markdown]
# 1. Count of all column is 214 so no null values
# 2. By seeing this very little skewnness is present in the dataset.
# 3. There is not much left & right skewness present in the dataset.
# 4. There might be less outliers are present in Potassium & Calcium column.

# %%
sns.violinplot(x='Potassium',data=df)
# Out:
# <AxesSubplot:xlabel='Potassium'>

# %%
sns.kdeplot(df['Calcium'])
# Out:
# <AxesSubplot:xlabel='Calcium', ylabel='Density'>

# %%
sns.distplot(df['refractive index'])
# Out:
# <AxesSubplot:xlabel='refractive index', ylabel='Density'>

# %%
sns.violinplot(df['Sodium'])
# Out:
# <AxesSubplot:xlabel='Sodium'>

# %%
sns.boxplot(x='Magnesium',data=df)
# Out:
# <AxesSubplot:xlabel='Magnesium'>

# %%
plt.hist(df['Aluminum'])
# Out:
# (array([ 8., 20., 44., 81., 31., 14.,  7.,  5.,  3.,  1.]),
#  array([0.29 , 0.611, 0.932, 1.253, 1.574, 1.895, 2.216, 2.537, 2.858,
#         3.179, 3.5  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.stripplot(df['Silicon'])
# Out:
# <AxesSubplot:xlabel='Silicon'>

# %%
sns.swarmplot(x='Barium',data=df)
# Out:
# <AxesSubplot:xlabel='Barium'>

# %%
sns.boxplot(x='Iron',data=df)
# Out:
# <AxesSubplot:xlabel='Iron'>

# %%
sns.scatterplot(x='refractive index',y='Sodium',data=df)         # Bivariant Analysis
# Out:
# <AxesSubplot:xlabel='refractive index', ylabel='Sodium'>

# %%
sns.stripplot(x='Sodium',y='Magnesium',data=df)
# Out:
# <AxesSubplot:xlabel='Sodium', ylabel='Magnesium'>

# %%
sns.swarmplot(x='Aluminum',y='Silicon',data=df)
# Out:
# <AxesSubplot:xlabel='Aluminum', ylabel='Silicon'>

# %%
sns.lineplot(x='Potassium',y='Calcium',data=df)
# Out:
# <AxesSubplot:xlabel='Potassium', ylabel='Calcium'>

# %%
sns.lmplot(x='Barium',y='Iron',data=df)

# %%
sns.lmplot(x='refractive index',y='Type of glass',data=df)

# %%
sns.scatterplot(x='Sodium',y='Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel='Sodium', ylabel='Type of glass'>

# %%
sns.scatterplot(x='Magnesium',y='Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel='Magnesium', ylabel='Type of glass'>

# %%
sns.stripplot(x='Aluminum',y='Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel='Aluminum', ylabel='Type of glass'>

# %%
sns.swarmplot(x='Silicon',y='Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel='Silicon', ylabel='Type of glass'>

# %%
sns.lineplot(x='Potassium',y='Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel='Potassium', ylabel='Type of glass'>

# %%
sns.lmplot(x='Calcium',y='Type of glass',data=df)

# %%
sns.scatterplot(x='Barium',y='Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel='Barium', ylabel='Type of glass'>

# %%
sns.swarmplot(x='Iron',y='Type of glass',data=df )
# Out:
# <AxesSubplot:xlabel='Iron', ylabel='Type of glass'>

# %%
sns.pairplot(df)             # Multivariant analysis

# %%
plt.figure(figsize=(15,8),facecolor='White')           # Checking the outliers.
pltno=1
for i in df.columns:
    if pltno<=11:
        ax=plt.subplot(3,5,pltno)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=15)
    pltno+=1
plt.tight_layout()

# %% [markdown]
# Outliers are present in almost all the columns except Id number

# %%
plt.figure(figsize=(14,8),facecolor='White')           # Checking the skewness.
pltno=1
for i in df.columns:
    if pltno<=11:
        ax=plt.subplot(3,5,pltno)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=15)
    pltno+=1
plt.tight_layout()

# %%
df.skew()                 # Checking Skewness
# Out:
# Id number           0.000000
# refractive index    1.625431
# Sodium              0.454181
# Magnesium          -1.152559
# Aluminum            0.907290
# Silicon            -0.730447
# Potassium           6.551648
# Calcium             2.047054
# Barium              3.416425
# Iron                1.754327
# Type of glass       1.114915
# dtype: float64

# %%
# Since Id number column gives unique values, no skewness, no Outliers so we can drop the columns.
df.drop(columns='Id number',inplace=True)

# %%
df          # Id number has removed from the column.
# Out:
#      refractive index  Sodium  Magnesium  Aluminum  Silicon  Potassium  \
# 0             1.52101   13.64       4.49      1.10    71.78       0.06
# 1             1.51761   13.89       3.60      1.36    72.73       0.48
# 2             1.51618   13.53       3.55      1.54    72.99       0.39
# 3             1.51766   13.21       3.69      1.29    72.61       0.57
# 4             1.51742   13.27       3.62      1.24    73.08       0.55
# ..                ...     ...        ...       ...      ...        ...
# 209           1.51623   14.14       0.00      2.88    72.61       0.08
# 210           1.51685   14.92       0.00      1.99    73.06       0.00
# 211           1.52065   14.36       0.00      2.02    73.42       0.00
# 212           1.51651   14.38       0.00      1.94    73.61       0.00
# 213           1.51711   14.23       0.00      2.08    73.36       0.00
#
#      Calcium  Barium  Iron  Type of glass
# 0       8.75    0.00   0.0              1
# ...

# %%
from scipy.stats import zscore
features=df.drop('Type of glass',axis=1)

z=np.abs(zscore(features))
z
# Out:
#      refractive index    Sodium  Magnesium  Aluminum   Silicon  Potassium  \
# 0            0.872868  0.284953   1.254639  0.692442  1.127082   0.671705
# 1            0.249333  0.591817   0.636168  0.170460  0.102319   0.026213
# 2            0.721318  0.149933   0.601422  0.190912  0.438787   0.164533
# 3            0.232831  0.242853   0.698710  0.310994  0.052974   0.112107
# 4            0.312045  0.169205   0.650066  0.411375  0.555256   0.081369
# ..                ...       ...        ...       ...       ...        ...
# 209          0.704815  0.898681   1.865511  2.881125  0.052974   0.640968
# 210          0.500178  1.856097   1.865511  1.094342  0.529374   0.763919
# 211          0.754046  1.168721   1.865511  1.154570  0.995252   0.763919
# 212          0.612399  1.193270   1.865511  0.993960  1.241133   0.763919
# 213          0.414363  1.009152   1.865511  1.275028  0.917606   0.763919
#
#       Calcium    Barium      Iron
# 0    0.145766  0.352877  0.586451
# ...

# %%
np.where(z>3)
# Out:
# (array([105, 106, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112,
#         131, 145, 162, 163, 163, 163, 171, 171, 172, 172, 174, 184, 184,
#         188, 189, 201, 201, 203, 207, 213], dtype=int64),
#  array([6, 0, 1, 4, 6, 7, 0, 4, 6, 6, 6, 0, 6, 6, 8, 8, 3, 4, 7, 3, 5, 3,
#         5, 8, 1, 4, 4, 7, 4, 5, 7, 7, 7], dtype=int64))

# %%
z.iloc[105,6]
# Out:
# 3.01659640155971

# %%
z.iloc[106,0]
# Out:
# 4.252673357413172

# %%
z.iloc[106,1]
# Out:
# 3.2869427542411156

# %%
df1=df[(z<3).all(axis=1)]                # Data loss is in acceptable range less than 10%
 
print('Old',df.shape[0])
print('New',df1.shape[0])
print("Data loss percentage : ",((df.shape[0]-df1.shape[0])/df.shape[0]*100))
# Out:
# Old 214
# New 194
# Data loss percentage :  9.345794392523365

# %%
df1.skew()
# Out:
# refractive index    0.952733
# Sodium              0.371482
# Magnesium          -1.528849
# Aluminum            0.658259
# Silicon            -0.425450
# Potassium           0.303175
# Calcium             1.077962
# Barium              3.188587
# Iron                1.486479
# Type of glass       1.284007
# dtype: float64

# %%
df1['Barium']=np.cbrt(df1['Barium'])

# %%
df1.skew()
# Out:
# refractive index    0.952733
# Sodium              0.371482
# Magnesium          -1.528849
# Aluminum            0.658259
# Silicon            -0.425450
# Potassium           0.303175
# Calcium             1.077962
# Barium              2.207594
# Iron                1.486479
# Type of glass       1.284007
# dtype: float64

# %%
df1['Barium']=np.cbrt(df1['Barium'])

df1.skew()
# Out:
# refractive index    0.952733
# Sodium              0.371482
# Magnesium          -1.528849
# Aluminum            0.658259
# Silicon            -0.425450
# Potassium           0.303175
# Calcium             1.077962
# Barium              1.923662
# Iron                1.486479
# Type of glass       1.284007
# dtype: float64

# %%
df1['Barium']=np.cbrt(df1['Barium'])
                                                # Almost skewness has reduced.
df1.skew()
# Out:
# refractive index    0.952733
# Sodium              0.371482
# Magnesium          -1.528849
# Aluminum            0.658259
# Silicon            -0.425450
# Potassium           0.303175
# Calcium             1.077962
# Barium              1.877873
# Iron                1.486479
# Type of glass       1.284007
# dtype: float64

# %%
df1.corr()            # Checking the correlation between two indepent variable and target variable.
# Out:
#                   refractive index    Sodium  Magnesium  Aluminum   Silicon  \
# refractive index          1.000000  0.050760   0.048147 -0.522197 -0.609011
# Sodium                    0.050760  1.000000  -0.487729  0.253127 -0.234718
# Magnesium                 0.048147 -0.487729   1.000000 -0.593457 -0.377464
# Aluminum                 -0.522197  0.253127  -0.593457  1.000000  0.335262
# Silicon                  -0.609011 -0.234718  -0.377464  0.335262  1.000000
# Potassium                -0.368238 -0.612183   0.482622  0.005827  0.072579
# Calcium                   0.690650  0.019987  -0.455582 -0.213304 -0.165712
# Barium                   -0.218213  0.492451  -0.571169  0.564634  0.181423
# Iron                     -0.020046 -0.209838   0.134065 -0.117764  0.023279
# Type of glass            -0.167355  0.533025  -0.810321  0.660262  0.262152
#
#                   Potassium   Calcium    Barium      Iron  Type of glass
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %% [markdown]
# Most of the column has highest positive & negative correlation so multicollinearity present in this dataset. Lets check with VIF values and will conclude

# %%
x=df1.drop('Type of glass',axis=1)
y=df1["Type of glass"]

# %%
x.shape
# Out:
# (194, 9)

# %%
y.shape
# Out:
# (194,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      refractive index    Sodium  Magnesium  Aluminum   Silicon  Potassium  \
# 0            1.291781  0.332127   1.233397 -0.729105 -1.612464  -1.319609
# 1           -0.197832  0.704398   0.551581 -0.141722  0.016082   0.172091
# 2           -0.824346  0.168328   0.513277  0.264928  0.461790  -0.147559
# 3           -0.175926 -0.308179   0.620529 -0.299864 -0.189629   0.491741
# 4           -0.281075 -0.218834   0.566903 -0.412822  0.616073   0.420708
# ..                ...       ...        ...       ...       ...        ...
# 189         -0.727959  1.419158  -2.206325  2.975928  0.221793  -1.532708
# 190         -0.802440  1.076668  -2.206325  3.292211 -0.189629  -1.248575
# 191         -0.530805  2.238153  -2.206325  1.281553  0.581788  -1.532708
# 192          1.134057  1.404267  -2.206325  1.349328  1.198921  -1.532708
# 193         -0.679766  1.434048  -2.206325  1.168595  1.524630  -1.532708
#
#       Calcium    Barium      Iron
# 0   -0.075653 -0.435755 -0.603056
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['FEATURES']=x.columns
vif
# Out:
#    VIF Values          FEATURES
# 0    5.169996  refractive index
# 1   14.667865            Sodium
# 2   37.449848         Magnesium
# 3    7.506136          Aluminum
# 4   11.221229           Silicon
# 5    5.085530         Potassium
# 6   22.061579           Calcium
# 7    2.963775            Barium
# 8    1.107585              Iron

# %% [markdown]
# VIF value of Magnesium, Silicon, Calcium is high & these columns has high correlation. We have very less number of rows so lets proceed with same vif values.

# %%
y.value_counts()      # The data was immbalace so lets do Oversampling by using smote method.
# Out:
# 1    70
# 2    68
# 7    23
# 3    16
# 5     9
# 6     8
# Name: Type of glass, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()          # Now the data become balanced.
# Out:
# 1    70
# 2    70
# 3    70
# 5    70
# 6    70
# 7    70
# Name: Type of glass, dtype: int64

# %%
x.shape
# Out:
# (420, 9)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve

# %%
# Finding the best random state
maxacc=0
maxrs=0
for i in range(1,420):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    rfc=RandomForestClassifier()
    rfc.fit(x_train,y_train)
    predict_rfc=rfc.predict(x_test)
    acc=accuracy_score(y_test,predict_rfc)
    if acc>maxacc:
        maxacc=acc
        maxrs=i
print("Best accuracy score is ",maxacc,"at random state ",maxrs)
# Out:
# Best accuracy score is  0.9880952380952381 at random state  139

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=maxrs,test_size=.20)

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predict_RFC=RFC.predict(x_test)
print("Accuracy score : ",accuracy_score(y_test,predict_RFC))
print("Confusion Matrix : ",confusion_matrix(y_test,predict_RFC))
print("Classification Report : ",classification_report(y_test,predict_RFC))
# Out:
# Accuracy score :  0.9761904761904762
# Confusion Matrix :  [[ 8  1  0  0  0  0]
#  [ 0 17  0  0  0  0]
#  [ 1  0 10  0  0  0]
#  [ 0  0  0 13  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]
# Classification Report :                precision    recall  f1-score   support
#
#            1       0.89      0.89      0.89         9
#            2       0.94      1.00      0.97        17
#            3       1.00      0.91      0.95        11
#            5       1.00      1.00      1.00        13
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           0.98        84
#    macro avg       0.97      0.97      0.97        84
# weighted avg       0.98      0.98      0.98        84

# %%
ETC=ExtraTreesClassifier()
ETC.fit(x_train,y_train)
predict_ETC=ETC.predict(x_test)
print("Accuracy score : ",accuracy_score(y_test,predict_ETC))
print("Confusion Matrix : ",confusion_matrix(y_test,predict_ETC))
print("Classification Report : ",classification_report(y_test,predict_ETC))
# Out:
# Accuracy score :  0.9761904761904762
# Confusion Matrix :  [[ 7  2  0  0  0  0]
#  [ 0 17  0  0  0  0]
#  [ 0  0 11  0  0  0]
#  [ 0  0  0 13  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]
# Classification Report :                precision    recall  f1-score   support
#
#            1       1.00      0.78      0.88         9
#            2       0.89      1.00      0.94        17
#            3       1.00      1.00      1.00        11
#            5       1.00      1.00      1.00        13
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           0.98        84
#    macro avg       0.98      0.96      0.97        84
# weighted avg       0.98      0.98      0.98        84

# %%
GBC=GradientBoostingClassifier()
GBC.fit(x_train,y_train)
predict_GBC=GBC.predict(x_test)
print("Accuracy score : ",accuracy_score(y_test,predict_GBC))
print("Confusion Matrix : ",confusion_matrix(y_test,predict_GBC))
print("Classification Report : ",classification_report(y_test,predict_GBC))
# Out:
# Accuracy score :  0.9285714285714286
# Confusion Matrix :  [[ 8  1  0  0  0  0]
#  [ 2 15  0  0  0  0]
#  [ 2  0  9  0  0  0]
#  [ 0  0  0 13  0  0]
#  [ 0  1  0  0 10  0]
#  [ 0  0  0  0  0 23]]
# Classification Report :                precision    recall  f1-score   support
#
#            1       0.67      0.89      0.76         9
#            2       0.88      0.88      0.88        17
#            3       1.00      0.82      0.90        11
#            5       1.00      1.00      1.00        13
#            6       1.00      0.91      0.95        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           0.93        84
#    macro avg       0.92      0.92      0.92        84
# weighted avg       0.94      0.93      0.93        84

# %%
ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
predict_ABC=ABC.predict(x_test)
print("Accuracy score : ",accuracy_score(y_test,predict_ABC))
print("Confusion Matrix : ",confusion_matrix(y_test,predict_ABC))
print("Classification Report : ",classification_report(y_test,predict_ABC))
# Out:
# Accuracy score :  0.5952380952380952
# Confusion Matrix :  [[ 0  8  0  0  0  1]
#  [ 1 14  0  0  0  2]
#  [ 0 11  0  0  0  0]
#  [ 0  0  0  2 11  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]
# Classification Report :                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         9
#            2       0.42      0.82      0.56        17
#            3       0.00      0.00      0.00        11
#            5       1.00      0.15      0.27        13
#            6       0.50      1.00      0.67        11
#            7       0.88      1.00      0.94        23
#
#     accuracy                           0.60        84
#    macro avg       0.47      0.50      0.41        84
# weighted avg       0.55      0.60      0.50        84

# %%
BC=BaggingClassifier()
BC.fit(x_train,y_train)
predict_BC=BC.predict(x_test)
print("Accuracy score : ",accuracy_score(y_test,predict_BC))
print("Confusion Matrix : ",confusion_matrix(y_test,predict_BC))
print("Classification Report : ",classification_report(y_test,predict_BC))
# Out:
# Accuracy score :  0.9166666666666666
# Confusion Matrix :  [[ 8  1  0  0  0  0]
#  [ 3 13  0  0  0  1]
#  [ 2  0  9  0  0  0]
#  [ 0  0  0 13  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]
# Classification Report :                precision    recall  f1-score   support
#
#            1       0.62      0.89      0.73         9
#            2       0.93      0.76      0.84        17
#            3       1.00      0.82      0.90        11
#            5       1.00      1.00      1.00        13
#            6       1.00      1.00      1.00        11
#            7       0.96      1.00      0.98        23
#
#     accuracy                           0.92        84
#    macro avg       0.92      0.91      0.91        84
# weighted avg       0.93      0.92      0.92        84

# %%
KNC=KNeighborsClassifier()
KNC.fit(x_train,y_train)
predict_KNC=KNC.predict(x_test)
print("Accuracy score : ",accuracy_score(y_test,predict_KNC))
print("Confusion Matrix : ",confusion_matrix(y_test,predict_KNC))
print("Classification Report : ",classification_report(y_test,predict_KNC))
# Out:
# Accuracy score :  0.8928571428571429
# Confusion Matrix :  [[ 7  2  0  0  0  0]
#  [ 5 10  2  0  0  0]
#  [ 0  0 11  0  0  0]
#  [ 0  0  0 13  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]
# Classification Report :                precision    recall  f1-score   support
#
#            1       0.58      0.78      0.67         9
#            2       0.83      0.59      0.69        17
#            3       0.85      1.00      0.92        11
#            5       1.00      1.00      1.00        13
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           0.89        84
#    macro avg       0.88      0.89      0.88        84
# weighted avg       0.90      0.89      0.89        84

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
predict_DTC=DTC.predict(x_test)
print("Accuracy score : ",accuracy_score(y_test,predict_DTC))
print("Confusion Matrix : ",confusion_matrix(y_test,predict_DTC))
print("Classification Report : ",classification_report(y_test,predict_DTC))
# Out:
# Accuracy score :  0.8333333333333334
# Confusion Matrix :  [[ 5  4  0  0  0  0]
#  [ 6 10  0  0  0  1]
#  [ 2  1  8  0  0  0]
#  [ 0  0  0 13  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]
# Classification Report :                precision    recall  f1-score   support
#
#            1       0.38      0.56      0.45         9
#            2       0.67      0.59      0.62        17
#            3       1.00      0.73      0.84        11
#            5       1.00      1.00      1.00        13
#            6       1.00      1.00      1.00        11
#            7       0.96      1.00      0.98        23
#
#     accuracy                           0.83        84
#    macro avg       0.83      0.81      0.82        84
# weighted avg       0.86      0.83      0.84        84

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(RFC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_RFC)-score.mean())
# Out:
# [0.9047619  0.86904762 0.88095238 0.80952381 0.91666667]
# 0.8761904761904763
# Difference between accuracy score and cross val score :  0.09999999999999987

# %%
score=cross_val_score(ETC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_ETC)-score.mean())
# Out:
# [0.91666667 0.88095238 0.86904762 0.82142857 0.91666667]
# 0.880952380952381
# Difference between accuracy score and cross val score :  0.09523809523809512

# %%
score=cross_val_score(GBC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_GBC)-score.mean())
# Out:
# [0.86904762 0.88095238 0.89285714 0.80952381 0.88095238]
# 0.8666666666666668
# Difference between accuracy score and cross val score :  0.061904761904761796

# %%
score=cross_val_score(ABC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_ABC)-score.mean())
# Out:
# [0.47619048 0.5        0.57142857 0.3452381  0.41666667]
# 0.4619047619047619
# Difference between accuracy score and cross val score :  0.13333333333333336

# %%
score=cross_val_score(BC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_BC)-score.mean())
# Out:
# [0.86904762 0.83333333 0.86904762 0.82142857 0.88095238]
# 0.8547619047619047
# Difference between accuracy score and cross val score :  0.06190476190476191

# %%
score=cross_val_score(KNC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_KNC)-score.mean())
# Out:
# [0.8452381  0.80952381 0.8452381  0.79761905 0.86904762]
# 0.8333333333333333
# Difference between accuracy score and cross val score :  0.059523809523809645

# %%
score=cross_val_score(DTC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_DTC)-score.mean())
# Out:
# [0.83333333 0.80952381 0.86904762 0.80952381 0.8452381 ]
# 0.8333333333333333
# Difference between accuracy score and cross val score :  1.1102230246251565e-16

# %%
from sklearn.model_selection import GridSearchCV
parameters={'criterion':['gini', 'entropy', 'log_loss'],
            'n_estimators':[20,35,45,100],
            'random_state':[46,123,248,389]}                      # Using hyperparameter tuning improving the model performance
gridscv=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)
gridscv.fit(x_train,y_train)
gridscv.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 45, 'random_state': 389}

# %%
final_model=ExtraTreesClassifier(criterion='entropy',n_estimators=45,random_state=389)
final_model.fit(x_train,y_train)
pred_fin_model=final_model.predict(x_test)               # Random Forest classifier working wel
acc=accuracy_score(y_test,pred_fin_model)
print(acc*100)
# Out:
# 97.61904761904762

# %%
y_pred_proba=final_model.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba,pos_label=1)            # Auc Roc curve 
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Random Forest Classifier') 
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()
auc_score=roc_auc_score(y_test,final_model.predict(x_test),multi_class='ovo')
print("Auc score : ",auc_score)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Input In [110], in <cell line: 8>()
#       6 plt.ylabel("True Positive Rate")
#       7 plt.show()
# ----> 8 auc_score=roc_auc_score(y_test,final_model.predict(x_test),multi_class='ovo')
#       9 print("Auc score : ",auc_score)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:561, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     559     if multi_class == "raise":
#     560         raise ValueError("multi_class must be in ('ovo', 'ovr')")
# --> 561     return _multiclass_roc_auc_score(
#     562         y_true, y_score, labels, multi_class, average, sample_weight
#     563     )
#     564 elif y_type == "binary":
#     565     labels = np.unique(y_true)
#
# ...

# %%
import joblib
joblib.dump(final_model,"Gls_identification.pkl")           # Saving the model

model=joblib.load("Gls_identification.pkl")
prediction=model.predict(x_test)                 # Reloading back the model
prediction

a=np.array(y_test)                                # Predicting the saved model
data1=pd.DataFrame()
data1['Predicted']=prediction
data1['Original']=a
data1
