# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt          # Importing the necessary libraries
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.sample(5)
# Out:
#       Country                           Region  Happiness Rank  \
# 91    Morocco  Middle East and Northern Africa              92
# 142     Gabon               Sub-Saharan Africa             143
# 109      Iran  Middle East and Northern Africa             110
# 127  Botswana               Sub-Saharan Africa             128
# 106   Tunisia  Middle East and Northern Africa             107
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 91             5.013         0.03420                   0.73479  0.64095
# 142            3.896         0.04547                   1.06024  0.90528
# 109            4.686         0.04449                   1.00880  0.54447
# 127            4.332         0.04934                   0.99355  1.10464
# 106            4.739         0.03589                   0.88113  0.60429
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 91                    0.60954  0.41691                        0.08546
# ...

# %%
df.shape   # This dataset contains 158 rows and 12 columns
# Out:
# (158, 12)

# %%
df.columns   # These are the 12 columns present in the dataset
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes  # Three types of data are present object,int64,float64
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()  # This is gives the information of 158 rows and 12 columns, three types of data are present, memory usage is 14.9+KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()  # No null values & wide values are present in this dataset
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())   # Visualizing with heatmap no null values
# Out:
# <AxesSubplot:>

# %%
for i in df.columns:
    print(df[i].value_counts())  #  By seeing this value count Happiness score is a continuos column 
    print("\n")
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
df['Happiness Score'].unique()    # Its a linear regression problem
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
df['Happiness Score'].nunique()
# Out:
# 157

# %%
df.duplicated().sum()         # No duplicate rows are present
# Out:
# 0

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# 1. Count of all count is 158 so no null values
# 2. Happiness score,standard error,trust,generosity,dystopia residual slightly mean is greater than median so the data is slightly right skewed.
# 3. Happiness rank,economy,family,health,freedom is mean is less than median so the data is slightly left skewed.
# 4. Maybe outliers are not present in this dataset.

# %%
sns.countplot(x='Country',data=df)         # Univariant analysis
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
df['Country'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 153         Rwanda
# 154          Benin
# 155          Syria
# 156        Burundi
# 157           Togo
# Name: Country, Length: 158, dtype: object>

# %%
sns.countplot(y='Region',data=df)   # Sub-saharan africa is the highest count
# Out:
# <AxesSubplot:xlabel='count', ylabel='Region'>

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
plt.violinplot(df['Standard Error'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1b8fd957250>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1b8fd9571c0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1b8fd9577f0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1b8fd957bb0>}

# %%
plt.boxplot(df['Happiness Rank'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b8fd9c1460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b8fd9c1a00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b8fd9c12b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b8fd9c1fa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b8fd9ce2b0>],
#  'means': []}

# %%
plt.violinplot(df['Economy (GDP per Capita)'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1b8fea02610>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1b8fea02580>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1b8fea02be0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1b8fea02fa0>}

# %%
plt.hist(df['Family'])
# Out:
# (array([ 2.,  0.,  7.,  4.,  9., 16., 28., 34., 34., 24.]),
#  array([0.      , 0.140223, 0.280446, 0.420669, 0.560892, 0.701115,
#         0.841338, 0.981561, 1.121784, 1.262007, 1.40223 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(df['Health (Life Expectancy)'])

# %%
sns.stripplot(x='Trust (Government Corruption)',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)'>

# %%
sns.swarmplot(x='Freedom',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.violinplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
sns.stripplot(x='Country',y='Happiness Score',data=df)          # Bivariant Analysis
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %%
sns.swarmplot(x='Region',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness Score'>

# %%
sns.catplot(x='Region',y='Standard Error',data=df)

# %%
sns.scatterplot(x='Standard Error',y='Economy (GDP per Capita)',data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Economy (GDP per Capita)'>

# %%
sns.lineplot(x='Family',y='Health (Life Expectancy)',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Health (Life Expectancy)'>

# %%
sns.relplot(x='Freedom',y='Trust (Government Corruption)',data=df)

# %%
sns.scatterplot(x='Happiness Score',y='Standard Error',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Standard Error'>

# %%
sns.stripplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.swarmplot(x='Family',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
sns.lineplot(x='Freedom',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.relplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.lineplot(x='Dystopia Residual',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %%
sns.pairplot(df)   # Multivariant analysis

# %%
categorical_col=[]                # Seperating numeric & Categoric columns
numeric_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
    else:
        numeric_col.append(i)
print("Categorical Column : ",categorical_col)
print("Numerical Column : ",numeric_col)
# Out:
# Categorical Column :  ['Country', 'Region']
# Numerical Column :  ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
plt.figure(figsize=(20,10),facecolor='White')
plot_number=1
for i in numeric_col:
    if plot_number<=10:                    # Checking how the datas are distributed in the dataset
        ax=plt.subplot(2,5,plot_number)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
    plot_number+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,15),facecolor='White')  # Checking the outliers
plot_no=1
for i in numeric_col:
    if plot_no<=10:
        ax=plt.subplot(2,5,plot_no)
        plt.boxplot(df[i])
        plt.xlabel(i,fontsize=20)
    plot_no+=1
plt.tight_layout()

# %% [markdown]
# By seeing this boxplot visualiazation outliers are present in the dataset in the column standard error,family,Trust,Generosity & Dystopia Residual

# %%
df.skew()   #  Checking the Skewness
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Standard Error']=np.cbrt(df['Standard Error'])         # Removing the skewness using cuberoot

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Trust (Government Corruption)']=np.cbrt(df['Trust (Government Corruption)'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.011932
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Generosity']=np.cbrt(df['Generosity'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.011932
# Generosity                      -0.961079
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Standard Error']=np.cbrt(df['Standard Error'])

# %%
df.skew()            # Skewness is reduced But if we are going to reduce the family column skewness but showing NAN values.
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.650861
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.011932
# Generosity                      -0.961079
# Dystopia Residual               -0.238911
# dtype: float64

# %%
from sklearn.preprocessing import OrdinalEncoder          # Encoding categorical column.
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587        0.687048
# 1       58.0     9.0               2            7.561        0.715004
# 2       37.0     9.0               3            7.527        0.685170
# 3      105.0     9.0               4            7.522        0.696953
# 4       24.0     5.0               5            7.427        0.690168
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465        0.688226
# 154     13.0     8.0             155            3.340        0.692363
# 155    136.0     4.0             156            3.006        0.717110
# 156     21.0     8.0             157            2.905        0.761965
# 157    141.0     8.0             158            2.839        0.740897
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.info()     # All the categorical column encoded as numeical column for machine to read the values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    float64
#  1   Region                         158 non-null    float64
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.709746                  0.846137    0.991046
# std          0.025034                  0.403121    0.272369
# min          0.641817                  0.000000    0.000000
# 25%          0.693839                  0.545808    0.856823
# ...

# %%
x=df.drop('Happiness Score',axis=1)         # Seperating the features & target variable

# %%
x
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0      135.0     9.0               1        0.687048
# 1       58.0     9.0               2        0.715004
# 2       37.0     9.0               3        0.685170
# 3      105.0     9.0               4        0.696953
# 4       24.0     5.0               5        0.690168
# ..       ...     ...             ...             ...
# 153    118.0     8.0             154        0.688226
# 154     13.0     8.0             155        0.692363
# 155    136.0     4.0             156        0.717110
# 156     21.0     8.0             157        0.761965
# 157    141.0     8.0             158        0.740897
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
y=df['Happiness Score']

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))                            # Applying the feature engineering
z
# Out:
#       Country    Region  Happiness Rank  Standard Error  \
# 0    1.238770  1.300256        1.721000        0.909597
# 1    0.449465  1.300256        1.699075        0.210704
# 2    0.909893  1.300256        1.677149        0.984853
# 3    0.581016  1.300256        1.655224        0.512654
# 4    1.194920  0.040302        1.633299        0.784541
# ..        ...       ...             ...             ...
# 153  0.866043  0.965117        1.633576        0.862389
# 154  1.436096  0.965117        1.655501        0.696582
# 155  1.260695  0.375441        1.677427        0.295095
# 156  1.260695  0.965117        1.699352        2.092613
# 157  1.370321  0.965117        1.721277        1.248335
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# ...

# %%
np.where(z>3)
# Out:
# (array([ 63,  64,  73, 101, 147, 155, 157], dtype=int64),
#  array([ 9,  3,  8,  9,  5, 10,  5], dtype=int64))

# %%
z.iloc[63,9]
# Out:
# 3.856885497527383

# %%
z.iloc[64,3]
# Out:
# 3.688129420515311

# %%
x1=x[(z<3).all(axis=1)]
y1=y[(z<3).all(axis=1)]           # Droping the outliers where standard deviation is more than 3

# %%
x1.shape
# Out:
# (151, 11)

# %%
x1
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0      135.0     9.0               1        0.687048
# 1       58.0     9.0               2        0.715004
# 2       37.0     9.0               3        0.685170
# 3      105.0     9.0               4        0.696953
# 4       24.0     5.0               5        0.690168
# ..       ...     ...             ...             ...
# 151     20.0     8.0             152        0.705394
# 152      0.0     7.0             153        0.679397
# 153    118.0     8.0             154        0.688226
# 154     13.0     8.0             155        0.692363
# 156     21.0     8.0             157        0.761965
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
y1.shape        # Data loss percentage is very less only 7 rows has removed from the data set.
# Out:
# (151,)

# %%
y1
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 151    3.587
# 152    3.575
# 153    3.465
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 151, dtype: float64

# %%
df.corr()       # Checking any multicolinearity is present in the dataset
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.022448 -0.057580        0.188137
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.059858  0.213506       -0.304207
# Generosity                     0.115876  0.269423       -0.141914
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,cmap='Oranges_r')         # Visualizing using heatmap
plt.show()

# %% [markdown]
# Happiness Rank is giving more negative correlation & Happiness score gives positive correlation to the other columns. so lets check with Variance inflation factor then we can decide any columns needs to be drop.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x1.values,i) for i in range(len(x1.columns))]
vif['Features']=x1.columns                                            
vif                                                   # Mulitcollinearity present in the dataset.
# Out:
#     VIF Values                       Features
# 0     4.193967                        Country
# 1     6.254463                         Region
# 2    69.851195                 Happiness Rank
# 3   774.042442                 Standard Error
# 4    38.505857       Economy (GDP per Capita)
# 5    47.244760                         Family
# 6    28.127832       Health (Life Expectancy)
# 7    22.064092                        Freedom
# 8    19.257041  Trust (Government Corruption)
# 9    51.870223                     Generosity
# 10   77.222583              Dystopia Residual

# %%
x1=x1.drop("Standard Error",axis=1)

x1
# Out:
#      Country  Region  Happiness Rank  Economy (GDP per Capita)   Family  \
# 0      135.0     9.0               1                   1.39651  1.34951
# 1       58.0     9.0               2                   1.30232  1.40223
# 2       37.0     9.0               3                   1.32548  1.36058
# 3      105.0     9.0               4                   1.45900  1.33095
# 4       24.0     5.0               5                   1.32629  1.32261
# ..       ...     ...             ...                       ...      ...
# 151     20.0     8.0             152                   0.25812  0.85188
# 152      0.0     7.0             153                   0.31982  0.30285
# 153    118.0     8.0             154                   0.22208  0.77370
# 154     13.0     8.0             155                   0.28665  0.35386
# 156     21.0     8.0             157                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# Standard Error column gives the highest correlation to other columns so we drop this column and check the other columns Vif Values.

# %%
vif=pd.DataFrame()
vif['Features']=x1.columns       
vif['VIF Values']=[variance_inflation_factor(x1.values,i) for i in range(len(x1.columns))]
vif
# Out:
#                         Features  VIF Values
# 0                        Country    4.166881
# 1                         Region    5.794126
# 2                 Happiness Rank    5.210799
# 3       Economy (GDP per Capita)   23.487290
# 4                         Family   31.751496
# 5       Health (Life Expectancy)   27.003027
# 6                        Freedom   19.460670
# 7  Trust (Government Corruption)   18.395481
# 8                     Generosity   43.706713
# 9              Dystopia Residual   13.358662

# %% [markdown]
# After removing the standard error column all other column vif Values has been reduced But vif value acceptable range is less than 10 but if we drop one more column it leads to data loss. so lets proceed with the same vif value and same columns.

# %%
x=x1
y=y1

# %%
from sklearn.preprocessing import StandardScaler          # Doing standard scaling to overcome biasness.
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Country    Region  Happiness Rank  Economy (GDP per Capita)    Family  \
# 0    1.242194  1.303819       -1.699730                  1.354873  1.374784
# 1   -0.441334  1.303819       -1.677684                  1.120057  1.584407
# 2   -0.900478  1.303819       -1.655638                  1.177795  1.418800
# 3    0.586274  1.303819       -1.633592                  1.510661  1.300986
# 4   -1.184710 -0.033204       -1.611546                  1.179815  1.267825
# ..        ...       ...             ...                       ...       ...
# 146 -1.272166  0.969563        1.629212                 -1.483135 -0.603875
# 147 -1.709446  0.635307        1.651258                 -1.329317 -2.786909
# 148  0.870506  0.969563        1.673304                 -1.572983 -0.914732
# 149 -1.425214  0.969563        1.695350                 -1.412010 -2.584085
# 150 -1.250302  0.969563        1.739442                 -2.088486 -2.337523
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,roc_auc_score,roc_curve
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor,ExtraTreesRegressor,AdaBoostRegressor,BaggingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
maxaccu=0
maxrs=0
for i in range(1,151):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    predict_lr=lr.predict(x_test)
    acc=r2_score(y_test,predict_lr)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print("Maximum R2 score is ",maxaccu, "on random state ",maxrs)
# Out:
# Maximum R2 score is  0.9993555459376089 on random state  24

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=maxrs)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
predict_LR=LR.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_LR))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_LR))
print("Mean Squared Error ",mean_squared_error(y_test,predict_LR))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_LR)))
# Out:
# R2 Score  0.9993555459376089
# Mean Absolute Error  0.025044795361048092
# Mean Squared Error  0.0008810218154236776
# Root Mean Squared Error  0.02968201164718587

# %%
lso=Lasso()
lso.fit(x_train,y_train)
predict_lso=lso.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_lso))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_lso))
print("Mean Squared Error ",mean_squared_error(y_test,predict_lso))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_lso)))
# Out:
# R2 Score  0.12309344915751619
# Mean Absolute Error  0.9718995987174394
# Mean Squared Error  1.1988035245113806
# Root Mean Squared Error  1.0948988649694458

# %%
rdg=Ridge()
rdg.fit(x_train,y_train)
predict_rdg=rdg.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_rdg))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_rdg))
print("Mean Squared Error ",mean_squared_error(y_test,predict_rdg))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_rdg)))
# Out:
# R2 Score  0.9992702345271621
# Mean Absolute Error  0.02631501690804452
# Mean Squared Error  0.000997649544371975
# Root Mean Squared Error  0.031585590771299105

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
predict_gbr=gbr.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_gbr))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_gbr))
print("Mean Squared Error ",mean_squared_error(y_test,predict_gbr))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_gbr)))
# Out:
# R2 Score  0.9988170622553505
# Mean Absolute Error  0.03240620191559416
# Mean Squared Error  0.0016171733877468576
# Root Mean Squared Error  0.0402140943917286

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predict_rfr=rfr.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_rfr))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_rfr))
print("Mean Squared Error ",mean_squared_error(y_test,predict_rfr))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_rfr)))
# Out:
# R2 Score  0.9986400139685433
# Mean Absolute Error  0.031049032258064848
# Mean Squared Error  0.0018592129870967577
# Root Mean Squared Error  0.043118592127952854

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
predict_etr=etr.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_etr))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_etr))
print("Mean Squared Error ",mean_squared_error(y_test,predict_etr))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_etr)))
# Out:
# R2 Score  0.9991038683241356
# Mean Absolute Error  0.025096451612903796
# Mean Squared Error  0.0012250858548387043
# Root Mean Squared Error  0.03500122647620658

# %%
abr=AdaBoostRegressor()
abr.fit(x_train,y_train)
predict_abr=abr.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_abr))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_abr))
print("Mean Squared Error ",mean_squared_error(y_test,predict_abr))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_abr)))
# Out:
# R2 Score  0.9968734176188205
# Mean Absolute Error  0.04370749024133275
# Mean Squared Error  0.004274295789707714
# Root Mean Squared Error  0.06537809870061774

# %%
br=BaggingRegressor()
br.fit(x_train,y_train)
predict_br=br.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_br))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_br))
print("Mean Squared Error ",mean_squared_error(y_test,predict_br))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_br)))
# Out:
# R2 Score  0.996930169264516
# Mean Absolute Error  0.04498709677419364
# Mean Squared Error  0.004196711612903246
# Root Mean Squared Error  0.06478203155893805

# %%
svr=SVR()
svr.fit(x_train,y_train)
predict_svr=svr.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_svr))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_svr))
print("Mean Squared Error ",mean_squared_error(y_test,predict_svr))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_svr)))
# Out:
# R2 Score  0.9538062779970093
# Mean Absolute Error  0.1743134334731123
# Mean Squared Error  0.06315062499451131
# Root Mean Squared Error  0.25129788099884826

# %%
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
predict_knr=knr.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_knr))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_knr))
print("Mean Squared Error ",mean_squared_error(y_test,predict_knr))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_knr)))
# Out:
# R2 Score  0.9238934969403232
# Mean Absolute Error  0.264083870967742
# Mean Squared Error  0.1040438619354839
# Root Mean Squared Error  0.32255830780726125

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
predict_dtr=dtr.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_dtr))
print("Mean Absolute Error ",mean_absolute_error(y_test,predict_dtr))
print("Mean Squared Error ",mean_squared_error(y_test,predict_dtr))
print("Root Mean Squared Error ",np.sqrt(mean_squared_error(y_test,predict_dtr)))
# Out:
# R2 Score  0.9920105814870256
# Mean Absolute Error  0.0745806451612903
# Mean Squared Error  0.010922193548387095
# Root Mean Squared Error  0.10450929886085301

# %% [markdown]
# Out of 11 models Linear Regression model is working wel lets do hyper parameter tuning by using GridSearchCV to improve the model performance.

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 Score and cross val score is : ",(r2_score(y_test,predict_LR)-score.mean())*100)
# Out:
# [0.90353295 0.93195085 0.95822184 0.95246551 0.96915706]
# 0.9430656411347424
# Difference between R2 Score and cross val score is :  5.628990480286644

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(rdg,x,y)
print(score)
print(score.mean())
print("Difference between R2 Score and cross val score is : ",(r2_score(y_test,predict_rdg)-score.mean())*100)
# Out:
# [0.81035345 0.91470491 0.95824678 0.94691227 0.96481676]
# 0.9190068308249515
# Difference between R2 Score and cross val score is :  8.026340370221064

# %%
from sklearn.model_selection import GridSearchCV
parameter={'fit_intercept':[True,bool],
           'copy_X':[True,bool],
           'n_jobs':[-1,1,2],
           'positive':[False,bool]}

# %%
gscv=GridSearchCV(LinearRegression(),parameter,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, <class 'bool'>],
#                          'fit_intercept': [True, <class 'bool'>],
#                          'n_jobs': [-1, 1, 2],
#                          'positive': [False, <class 'bool'>]})

# %%
gscv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': -1, 'positive': bool}

# %%
final_model=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, positive=bool)
final_model.fit(x_train,y_train)
final_predict=final_model.predict(x_test)
acc=r2_score(y_test,final_predict)                         # Linear Regression performing wel.
print(acc*100)
# Out:
# 99.92384368301033

# %%
import joblib
joblib.dump(final_model,'Happiness_score.pkl')           # Saving the model
# Out:
# ['Happiness_score.pkl']

# %%
model=joblib.load("Happiness_score.pkl")
prediction=model.predict(x_test)
prediction                                              # Predicting the saved model
a=np.array(y_test)
df=pd.DataFrame()
df['Predicted']=prediction
df['Original']=a
df
# Out:
#     Predicted  Original
# 0    4.748542     4.677
# 1    4.502562     4.518
# 2    5.842135     5.824
# 3    5.810143     5.791
# 4    4.718987     4.686
# 5    7.257122     7.226
# 6    5.983480     5.960
# 7    5.385295     5.332
# 8    6.577057     6.574
# 9    3.357421     3.340
# 10   6.458209     6.505
# 11   6.900307     6.901
# 12   6.715413     6.670
# 13   4.565050     4.571
# 14   3.589586     3.575
# 15   7.166072     7.119
# 16   4.741592     4.715
# 17   6.530104     6.485
# 18   4.728022     4.694
# 19   4.410985     4.419
# 20   4.603551     4.565
# 21   3.830054     3.819
# 22   3.950622     3.931
# 23   5.828770     5.889
# 24   3.949258     3.904
# 25   7.581141     7.561
# 26   4.660213     4.642
# 27   3.894539     3.896
# 28   5.970862     5.948
# 29   4.628633     4.633
# 30   5.220833     5.192
